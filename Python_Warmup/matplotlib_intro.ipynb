# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5, 11)
y_1 = np.exp(x)
y_2 = np.log(x)

fig, (ax_1, ax_2) = plt.subplots(1, 2)
ax_1.plot(x, y_1)
ax_2.plot(x, y_2)
fig.show()
# Out:
# /var/folders/x2/02wgr6dd7dq4_fsbqpfv7ybr0000gn/T/ipykernel_82299/3522952898.py:6: RuntimeWarning: divide by zero encountered in log
#   y_2 = np.log(x)
# /var/folders/x2/02wgr6dd7dq4_fsbqpfv7ybr0000gn/T/ipykernel_82299/3522952898.py:6: RuntimeWarning: invalid value encountered in log
#   y_2 = np.log(x)
# /var/folders/x2/02wgr6dd7dq4_fsbqpfv7ybr0000gn/T/ipykernel_82299/3522952898.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
